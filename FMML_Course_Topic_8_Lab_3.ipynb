# %% [markdown]
# <a href="https://colab.research.google.com/github/21JN1A4218/FMML-MODULUS---IIIT-HYBERABAD/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-26 06:02:15--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   115MB/s    in 0.6s
#
# 2024-03-26 06:02:17 (115 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 15278   1008.1986v1  We report on work in progress on extracting le...    cs
# 30307  1711.10914v1  Spatio-temporal feature encoding is essential ...    cs
# 7202   1711.00837v2  Learning from class-imbalanced data continues ...    cs
# 16194  1610.07149v1  Open-domain human-computer conversation has at...    cs
# 36985  1602.02710v1  We study the strategic aspects of social influ...    cs
# ...             ...                                                ...   ...
# 6487   1702.07790v1  Many activation functions have been proposed i...  stat
# 19954   1303.5706v1  An approach to reasoning with default rules wh...    cs
# 12630  1803.07617v1  We uncover a fairly general principle in onlin...    cs
# 9717   1711.02837v1  Deep convolutional neural networks (CNNs) have...  stat
# 341    1701.03102v1  Limited annotated data available for the recog...    cs
#
#                                                    title  year  \
# 15278  For the sake of simplicity: Unsupervised extra...  2010
# 30307  Learning Spatio-temporal Features with Partial...  2017
# 7202   Oversampling for Imbalanced Learning Based on ...  2017
# 16194  Two are Better than One: An Ensemble of Retrie...  2016
# 36985  Strategic disclosure of opinions on a social n...  2016
# ...                                                  ...   ...
# 6487       Activation Ensembles for Deep Neural Networks  2017
# 19954  Constraint Propagation with Imprecise Conditio...  2013
# 12630  Online Learning: Sufficient Statistics and the...  2018
# 9717   Revealing structure components of the retina b...  2017
# 341    Linear Disentangled Representation Learning fo...  2017
#
#                                                 keywords
# 15278  [extracting, simplifications, collaborate, uti...
# 30307  [essential, expression, sequences, temporally,...
# 7202   [imbalanced, continues, challenging, supervise...
# 16194  [conversation, attracted, attention, conversat...
# 36985  [strategic, influence, introducing, influence,...
# ...                                                  ...
# 6487   [activation, functions, selecting, methodology...
# 19954  [reasoning, proportion, exceptions, generally,...
# 12630  [principle, expressed, sufficient, statistics,...
# 9717   [convolutional, demonstrated, impressive, perf...
# 341    [annotated, available, recognition, expression...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 15278    [extracting, simplifications, collaborate, uti...
# 30307    [essential, expression, sequences, temporally,...
# 7202     [imbalanced, continues, challenging, supervise...
# 16194    [conversation, attracted, attention, conversat...
# 36985    [strategic, influence, introducing, influence,...
#                                ...
# 22277    [probabilistic, segmentation, multivariate, va...
# 6902     [generating, processes, demonstrate, different...
# 8724     [collision, avoidance, accurately, probability...
# 21560    [concentration, inequalities, validation, gene...
# 31374    [observation, different, resolutions, resoluti...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8716 words.
# Out of those 4553 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="79b7e7f3-08f0-443d-82d7-ed899a83b2c8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("79b7e7f3-08f0-443d-82d7-ed899a83b2c8")) {                    Plotly.newPlot(                        "79b7e7f3-08f0-443d-82d7-ed899a83b2c8",                        [{"x":["wikipedia","different","outperform","extracting","unsupervised","utilizing","operations","collaborate","simplicity","histories","simplification","reasonable","independently","extraction","approaches","probabilities","temporally","available","predicting","auxiliary","expression","segmentation","tolerated","segmented","recognition","objective","accurately","interactive","estimated","affective","therefore","prediction","experimental","sequences","essential","importantly","intensity","performed","oversampled","algorithms","classifier","modifications","distributions","effectively","empirical","distribution","artificial","challenging","imbalanced","versatile","effective","programming","overcomes","supervised","clustering","generation","experiments","extensive","continues","classification","algorithm","unnecessary","strategies","consistently","imbalances","outperforms","implementation","techniques","recurrent","generator","conversation","utterance","utterances","generating","typically","retrieved","categories","meaningless","information","reranking","generative","generated","retrieval","synthesize","attention","candidate","attracted","invisible","incomplete","interaction","abstraction","considering","expressed","influence","strategic","behaviour","introducing","disclosure","equilibrium","considers","structure","dominance","prototypes","increases","contained","propagation","demonstrate","plasticity","databases","remarkable","processing","increased","architectures","convolutional","relatively","comprising","progressively","consumption","trainable","extracted","superiority","prototypical","reasonably","hierarchy","activated","corresponding","robustness","detectors","combination","dependent","understanding","complexity","demonstrated","thousands","intermediate","generally","previously","significantly","transform","published","technology","stabilization","conversational","performance","inventory","recognizers","initialization","connections","community","variables","simulations","dimensional","relationships","resulting","collections","statistical","estimating","generalize","inferring","uncovering","evaluated","applicable","highlight","qualitative","aggregate","simultaneously","evaluation","specifically","parameters","detection","mechanism","integrated","benchmarks","complementary","contextual","introduce","framework","quantitative","aggregating","innovations","movements","acceleration","mechanisms","continuous","characteristics","euclidean","accelerometer","implemented","regression","collection","environment","environments","individuals","authentication","neighbors","perceptrons","respectively","classifiers","separated","multilayer"],"y":[23,802,91,63,164,41,58,1,17,7,8,38,50,133,422,68,20,324,92,21,53,197,2,29,394,169,65,38,77,5,143,205,378,92,59,22,36,126,1,607,163,15,99,114,142,227,143,292,11,3,228,137,15,226,150,134,629,184,11,548,798,12,106,40,1,269,129,418,134,35,8,11,16,98,111,14,95,4,667,3,114,170,105,16,134,50,24,2,34,63,30,71,33,63,12,30,51,2,15,32,344,9,6,59,29,71,590,10,47,36,296,52,118,416,48,10,14,30,22,125,42,3,9,34,3,147,101,38,152,66,157,224,94,36,29,75,96,276,69,40,42,3,17,908,6,3,34,57,72,124,34,181,72,149,20,154,61,48,27,3,121,46,20,57,23,116,248,173,244,345,103,46,87,36,57,307,536,61,11,8,16,15,47,123,97,30,3,89,132,71,128,92,42,10,19,8,85,125,11,17],"type":"bar"},{"x":["wikipedia","different","outperform","extracting","unsupervised","utilizing","operations", ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4553,), (4553, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Image</span> <span style='background-color:rgba(0, 255, 0, 0.6923076923076923);'>Captioning</span> <span style=''>at</span> <span style=''>Will</span> <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.4545454545454545);'>Versatile</span> <span style=''>Scheme</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.39877300613496935);'>Effectively</span> <span style='background-color:rgba(255, 0, 0, 0.6);'>Injecting</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857142);'>Sentiments</span> <span style=''>into</span> <span style=''>Image</span> <span style='background-color:rgba(0, 255, 0, 0.8245614035087719);'>Descriptions</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.6153846153846154);'>Automatic</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.6923076923076923);'>captioning</span> <span style=''>has</span> <span style=''>recently</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approached</span> <span style=''>human</span> <span style=''>level</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>due</span> <span style=''>to</span> <span style=''>the</span> <span style=''>latest</span> <span style=''>advances</span> <span style=''>in</span> <span style=''>computer</span> <span style=''>vision</span> <span style=''>and</span> <span style=''>natural</span> <span style=''>language</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>understanding</span> <span style=''>However</span> <span style=''>most</span> <span style=''>of</span> <span style=''>the</span> <span style=''>current</span> <span style=''>models</span> <span style=''>can</span> <span style=''>only</span> <span style=''>generate</span> <span style=''>plain</span> <span style=''>factual</span> <span style='background-color:rgba(0, 255, 0, 0.8245614035087719);'>descriptions</span> <span style=''>about</span> <span style=''>the</span> <span style=''>content</span> <span style=''>of</span> <span style=''>a</span> <span style=''>given</span> <span style=''>image</span> <span style=''>However</span> <span style=''>for</span> <span style=''>human</span> <span style=''>beings</span> <span style=''>image</span> <span style=''>caption</span> <span style=''>writing</span> <span style=''>is</span> <span style=''>quite</span> <span style=''>flexible</span> <span style=''>and</span> <span style=''>diverse</span> <span style=''>where</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>additional</span> <span style=''>language</span> <span style='background-color:rgba(255, 0, 0, 0.3805309734513275);'>dimensions</span> <span style=''>such</span> <span style=''>as</span> <span style=''>emotion</span> <span style=''>humor</span> <span style=''>and</span> <span style=''>language</span> <span style=''>styles</span> <span style=''>are</span> <span style=''>often</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>incorporated</span> <span style=''>to</span> <span style=''>produce</span> <span style=''>diverse</span> <span style='background-color:rgba(0, 255, 0, 0.8666666666666667);'>emotional</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>appealing</span> <span style=''>captions</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>we</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interested</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generating</span> <span style='background-color:rgba(0, 255, 0, 0.6896551724137931);'>sentiment</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>conveying</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.8245614035087719);'>descriptions</span> <span style=''>which</span> <span style=''>has</span> <span style=''>received</span> <sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Dimensionality</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reduction</span> <span style=''>methods</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>molecular</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simulations</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Molecular</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simulations</span> <span style=''>produce</span> <span style=''>very</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>with</span> <span style=''>millions</span> <span style=''>of</span> <span style=''>data</span> <span style=''>points</span> <span style=''>As</span> <span style=''>analysis</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>often</span> <span style=''>unable</span> <span style=''>to</span> <span style=''>cope</span> <span style=''>with</span> <span style=''>so</span> <span style=''>many</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensions</span> <span style=''>it</span> <span style=''>is</span> <span style=''>common</span> <span style=''>to</span> <span style=''>use</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensionality</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reduction</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>methods</span> <span style=''>to</span> <span style=''>reach</span> <span style=''>a</span> <span style=''>reduced</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>data</span> <span style=''>Yet</span> <span style=''>these</span> <span style=''>methods</span> <span style=''>often</span> <span style=''>fail</span> <span style=''>to</span> <span style=''>capture</span> <span style=''>the</span> <span style=''>most</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>features</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>necessary</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>construction</span> <span style=''>of</span> <span style=''>a</span> <span style=''>Markov</span> <span style=''>model</span> <span style=''>Here</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>the</span> <span style=''>results</span> <span style=''>of</span> <span style=''>various</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensionality</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reduction</span> <span style=''>methods</span> <span style=''>on</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simulation</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>one</span> <span style=''>of</span> <span style=''>protein</span> <span style=''>folding</span> <span style=''>and</span> <span style=''>another</span> <span style=''>of</span> <span style=''>protein</span> <span style=''>ligand</span> <span style=''>binding</span> <span style=''>The</span> <span style=''>methods</span> <span style=''>tested</span> <span style=''>include</span> <span style=''>a</span> <span style=''>k</span> <span style=''>means</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>variant</span> <span style=''>a</span> <span style=''>non</span> <span style=''>linear</span> <span style=''>auto</span> <span style=''>encoder</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>component</span> <span style=''>analysis</span> <span st ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Testing</span> <span style='background-color:rgba(0, 255, 0, 0.510204081632653);'>Hypotheses</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3868613138686131);'>Regularized</span> <span style=''>Maximum</span> <span style=''>Mean</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Discrepancy</span> <br/><br/><span style=''>Do</span> <span style=''>two</span> <span style=''>data</span> <span style=''>samples</span> <span style=''>come</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3535864978902954);'>different</span> <span style='background-color:rgba(255, 0, 0, 0.37735849056603776);'>distributions</span> <span style=''>Recent</span> <span style=''>studies</span> <span style=''>of</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>fundamental</span> <span style=''>problem</span> <span style=''>focused</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>embedding</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style='background-color:rgba(255, 0, 0, 0.37735849056603776);'>distributions</span> <span style=''>into</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sufficiently</span> <span style=''>rich</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>characteristic</span> <span style='background-color:rgba(255, 0, 0, 0.7741935483870968);'>Reproducing</span> <span style=''>Kernel</span> <span style=''>Hilbert</span> <span style=''>Spaces</span> <span style=''>(RKHSs)</span> <span style=''>to</span> <span style=''>compare</span> <span style='background-color:rgba(255, 0, 0, 0.37735849056603776);'>distributions</span> <span style=''>by</span> <span style=''>the</span> <span style=''>distance</span> <span style=''>between</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3759999999999999);'>embeddings</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3868613138686131);'>Regularized</span> <span style=''>Maximum</span> <span style=''>Mean</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Discrepancy</span> <span style=''>(RMMD)</span> <span style=''>our</span> <span style=''>novel</span> <span style=''>measure</span> <span style=''>for</span> <span style=''>kernel</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hypothesis</span> <span style=''>testing</span> <span style=''>yields</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>substantial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>improvements</span> <span style=''>even</span> <span style=''>when</span> <span style=''>sample</span> <span style=''>sizes</span> <span style=''>are</span> <span style=''>small</span> <span style=''>and</span> <span style=''>excels</span> <span style=''>at</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hypothesis</span> <span style=''>tests</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>involving</span> <span style=''>multiple</span> <span style='background-color:rgba(255, 0, 0, 0.3243243243243244);'>comparisons</span> <span style=''>with</span> <span style=''>power</span> <span style=''>control</span> <span style=''>We</span> <span style=''>derive</span> <span style='background-color:rgba(255, 0, 0, 0.6545454545454547);'>asymptotic</span> <span style='background-color:rgba(255, 0, 0, 0.37735849056603776);'>distributions</span> <span style=''>under</span> <span style=''>the</span> <span style=''>null</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alternative</span> <span style='background-color:rgba(0, 255, 0, 0.510204081632653);'>hypotheses</span> <span style=''>and</span> <span style=''>assess</span> <span style=''>power</span> <span style=''>control</span> <span style='background-color ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>New</span> <span style=''>Spectral</span> <span style=''>Method</span> <span style=''>for</span> <span style=''>Latent</span> <span style=''>Variable</span> <span style=''>Models</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unsupervised</span> <span style=''>learning</span> <span style=''>of</span> <span style=''>latent</span> <span style=''>variable</span> <span style=''>models</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unlabeled</span> <span style=''>sets</span> <span style=''>of</span> <span style=''>data</span> <span style=''>We</span> <span style=''>base</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technique</span> <span style=''>on</span> <span style=''>spectral</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposition</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>providing</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technique</span> <span style=''>that</span> <span style=''>proves</span> <span style=''>to</span> <span style=''>be</span> <span style=''>robust</span> <span style=''>both</span> <span style=''>in</span> <span style=''>theory</span> <span style=''>and</span> <span style=''>in</span> <span style=''>practice</span> <span style=''>We</span> <span style=''>also</span> <span style=''>describe</span> <span style=''>how</span> <span style=''>to</span> <span style=''>use</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>of</span> <span style=''>two</span> <span style=''>well</span> <span style=''>known</span> <span style=''>text</span> <span style=''>mining</span> <span style=''>models</span> <span style=''>single</span> <span style=''>topic</span> <span style=''>model</span> <span style=''>and</span> <span style=''>Latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dirichlet</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Allocation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>providing</span> <span style=''>in</span> <span style=''>both</span> <span style=''>cases</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technique</span> <span style=''>to</span> <span style=''>retrieve</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>to</span> <span style=''>feed</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>We</span> <span style=''>compare</span> <span style=''>the</span> <span style=''>results</span> <span style=''>of</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>with</span> <span style=''>those</span> <span style=''>of</span> <span style=''>existing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>synthetic</span> <span style=''>data</span> <span style=''>and</span> <span style=''>we</span> <span style=''>provide</span> <span style=''>examples</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>to</span> <span style=''>real</span> <span style=''>world</span> <span style=''>text</span> <span style=''>corpora</span> <span style=''>for</ ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	challenging (0.10387762362148702)
# 	automatic (0.07470651013874066)
# 	information (0.23728210601209535)
# 	segmentation (0.07008182141586625)
# 	experimental (0.1344717182497332)
# 	representation (0.1326929918178584)
# 	detection (0.12273212379935966)
# 	different (0.28530771967271434)
# 	convolutional (0.1479900391319815)
# 	recognition (0.1401636428317325)
#
# Some Statistics words are:
# 	statistical (0.1493212669683258)
# 	distribution (0.17998994469582705)
# 	estimation (0.17496229260935142)
# 	stochastic (0.1437908496732026)
# 	theoretical (0.1558572146807441)
# 	variables (0.1503267973856209)
# 	algorithm (0.3941679235796883)
# 	dimensional (0.18552036199095023)
# 	inference (0.20110608345902464)
# 	regression (0.18149824032176973)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="736f748e-d3af-408d-b71d-d41ca3cae4bc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("736f748e-d3af-408d-b71d-d41ca3cae4bc")) {                    Plotly.newPlot(                        "736f748e-d3af-408d-b71d-d41ca3cae4bc",                        [{"x":["wikipedia","different","outperform","extracting","unsupervised","utilizing","operations","collaborate","simplicity","histories","simplification","reasonable","independently","extraction","approaches","probabilities","temporally","available","predicting","auxiliary","expression","segmentation","tolerated","segmented","recognition","objective","accurately","interactive","estimated","affective","therefore","prediction","experimental","sequences","essential","importantly","intensity","performed","oversampled","algorithms","classifier","modifications","distributions","effectively","empirical","distribution","artificial","challenging","imbalanced","versatile","effective","programming","overcomes","supervised","clustering","generation","experiments","extensive","continues","classification","algorithm","unnecessary","strategies","consistently","imbalances","outperforms","implementation","techniques","recurrent","generator","conversation","utterance","utterances","generating","typically","retrieved","categories","meaningless","information","reranking","generative","generated","retrieval","synthesize","attention","candidate","attracted","invisible","incomplete","interaction","abstraction","considering","expressed","influence","strategic","behaviour","introducing","disclosure","equilibrium","considers","structure","dominance","prototypes","increases","contained","propagation","demonstrate","plasticity","databases","remarkable","processing","increased","architectures","convolutional","relatively","comprising","progressively","consumption","trainable","extracted","superiority","prototypical","reasonably","hierarchy","activated","corresponding","robustness","detectors","combination","dependent","understanding","complexity","demonstrated","thousands","intermediate","generally","previously","significantly","transform","published","technology","stabilization","conversational","performance","inventory","recognizers","initialization","connections","community","variables","simulations","dimensional","relationships","resulting","collections","statistical","estimating","generalize","inferring","uncovering","evaluated","applicable","highlight","qualitative","aggregate","simultaneously","evaluation","specifically","parameters","detection","mechanism","integrated","benchmarks","complementary","contextual","introduce","framework","quantitative","aggregating","innovations","movements","acceleration","mechanisms","continuous","characteristics","euclidean","accelerometer","implemented","regression","collection","environment","environments","individuals","authentication","neighbors","perceptrons","respectively","classifiers","separated","multilayer","magnitude","extensively","laborious","achievable","sufficient","simulated","complexes","microscopy","automated","additional","efficient","comparisons","automatically","accelerate","reconstruction","structural","bottleneck","comparing","microscopes","particles","identification","throughput","maintaining","automatic","characteristic","resolution","decisions","represented","limitation","solutions","according","demanding","optimized","affecting","computationally","applications","decoupling","reduction","application","developed","separately","similarity","empirically","drastically","compromising","reference","interpret","similarities","naturally","representative","regularization","synthetic","additionally","consistency","orthogonality","redundant","approp ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	solvation
# 	unnecessarily
# 	unregularized
# 	metabolite
# 	stringent
# 	bernsteins
# 	supermodular
# 	distributedly
# 	tightness
# 	interacts
# 	linearnonlinear
# 	penalization
# 	procrustes
# 	predictivity
# 	methylation
# 	multisensor
# 	distinguishability
# 	nonconjugate
# 	embarrassingly
# 	cytometry
# Some words which never appear in Statistics papers:
# 	affective
# 	utterance
# 	meaningless
# 	invisible
# 	stabilization
# 	conversational
# 	accelerometer
# 	authentication
# 	programmer
# 	abbreviations
# 	harmonics
# 	lambertian
# 	illumination
# 	monomodal
# 	monocular
# 	questioning
# 	subjectively
# 	accumulative
# 	intermodal
# 	lifecycle

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0615681351988485e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.74
# Accuracy: 0.74
